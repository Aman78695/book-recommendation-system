# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/book-recommendation-system/blob/main/Book_Recommendation_System(UNSUPERVISED_LEARNING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ![1_778Oka9g5UJrZ48fWywtxg.png](data:image/png;base64,...)
#
# ## **Book Recommendation Syste**
#
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# # **What actually is Recommendation System**
#
#
# A recommendation engine is a class of machine learning which offers relevant suggestions to the customer.  Before the recommendation system, the major tendency to buy was to take a suggestion from friends. But Now Google knows what news you will read, Youtube knows what type of videos you will watch based on your search history, watch history, or purchase history.
#
# A recommendation system helps an organization to create loyal customers and build trust by them desired products and services for which they came on your site. The recommendation system today are so powerful that they can handle the new customer too who has visited the site for the first time. They recommend the products which are currently trending or highly rated and they can also recommend the products which bring maximum profit to the company.
#
#
# During the last few decades, with the rise of Youtube, Amazon, Netflix, and many other such web services, recommender systems have taken more and more place in our lives. From e-commerce (suggest to buyers articles that
# could interest them) to online advertisement (suggest to users the right contents, matching their preferences), recommender systems are today unavoidable in our daily online journeys.
#
# In a very general way, recommender systems are algorithms aimed at suggesting relevant items to users (items being movies to watch, text to read, products to buy, or anything else depending on industries).
#
# Recommendation systems are really critical in some industries as they can generate a huge amount of income when they are efficient or also be a way to stand out significantly from competitors. The main objective is to create a book recommendation system for users.
#
# Since, here we are trying to recommend books to users based on their past purchases or ratings the user gave previously, we are basically trying different models like Popularity based recommender system, Collaborative filtering based recommender system (user-item or item-item) etc. We will be using the Popularity based recommender system to deal with the cold start problem, where we do not have history of past purchases of a particular user or where the user is totally new.
#
# **Types Of Recommendation System**
#
# A recommendation system is usually built using 3 techniques which are content-based filtering, collaborative filtering, and a combination of both
#
# **1) Content-Based Filtering**
#
#
# The algorithm recommends a product that is similar to those which used as watched. In simple words, In this algorithm, we try to find finding item look alike. For example, a person likes to watch Sachin Tendulkar shots, so he may like watching Ricky Ponting shots too because the two videos have similar tags and similar categories.
#
# Only it looks similar between the content and does not focus more on the person who is watching this. Only it recommends the product which has the highest score based on past preferences.
#
# **2) Collaborative-based Filtering**
#
#
# Collaborative based filtering recommender systems are based on past interactions of users and target items.  In simple words here, we try to search for the look-alike customers and offer products based on what his or her lookalike has chosen. Let us understand with an example. X and Y are two similar users and X user has watched A, B, and C movie. And Y user has watched B, C, and D movie then we will recommend A movie to Y user and D movie to X user.
#
# Youtube has shifted its recommendation system from content-based to Collaborative based filtering technique. If you have experienced sometimes there are also videos which not at all related to your history but then also it recommends it because the other person similar to you has watched it.
#
# **3) Hybrid Filtering Method**
#
# It is basically a combination of both the above methods. It is a too complex model which recommends product based on your history as well based on similar users like you.
#
# There are some organizations that use this method like Facebook which shows news which is important for you and for others also in your network and the same is used by Linkedin too.

# %% [markdown]
# # **Book Recommendation System**
#
#
# A book recommendation system is a type of recommendation system where we have to recommend similar books to the reader based on his interest. The books recommendation system is used by online websites which provide ebooks like google play books, open library, good Read’s, etc.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Since, here we are trying to recommend books to users based on their past purchases or ratings the user gave previously, we are basically trying different models like Popularity based recommender system, Collaborative filtering based recommender system (user-item or item-item) etc. We will be using the Popularity based recommender system to deal with the cold start problem, where we do not have history of past purchases of a particular user or where the user is totally new.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np   #to perform a wide variety of mathematical operations on arrays
import pandas as pd   #for data analysis and associated manipulation of tabular data in DataFrames
import seaborn as sns    #for data visualization
import matplotlib.pyplot as plt    #for data visualization

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
users_df=pd.read_csv('/content/Users.csv',engine='python')  #contains information about users their country

# %%
books_df=pd.read_csv('/content/Books.csv',engine='python')  #contains information about books

# %%
rating_df=pd.read_csv('/content/Ratings.csv',engine='python') #contains the rating given by users

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look checking the first two rows of users datasets
users_df.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
#checking the shape of users datset 
users_df.shape
# Out:
# (278858, 3)

# %%
#checking null values in users dataframe
users_df.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
#checking the first two rows of books datasets
books_df.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
#checking null values in books dataframe
books_df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
#checking the shape of books datasets
books_df.shape
# Out:
# (271360, 8)

# %%
#checking the first two rows of rating datasets
rating_df.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
#checking the shape of rating datasets
rating_df.shape
# Out:
# (1149780, 3)

# %%
#checking null values in ratings dataframe
rating_df.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
#metging two datasets books and ratings on ISBN by default it is inner join
books=rating_df.merge(books_df,on='ISBN')

# %%
#shape of the merged datasets
books.shape
# Out:
# (1031136, 10)

# %%
#checking the first two rows of books
books.head(2)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...

# %%
#merging the two datasets
final_df=books.merge(users_df,on='User-ID')

# %%
#checking the first two rows of final datasets
final_df.head(2)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L               Location  \
# 0  http://images.amazon.com/images/P/034545104X.0...      tyler, texas, usa
# 1  http://images.amazon.com/images/P/034545104X.0...  cincinnati, ohio, usa
#
#     Age
# 0   NaN
# 1  23.0

# %%
final_df.shape
# Out:
# (1031136, 12)

# %%
#frequency of book in the datrasets
final_df['Book-Title'].value_counts()
# Out:
# Wild Animus                                                                         2502
# The Lovely Bones: A Novel                                                           1295
# The Da Vinci Code                                                                    898
# A Painted House                                                                      838
# The Nanny Diaries: A Novel                                                           828
#                                                                                     ...
# The Ambitious Generation: America's Teenagers, Motivated but Directionless             1
# Content Critical: Gaining Competitive Advantage through High-Quality Web Content       1
# The Virtual Community: Homesteading on the Electronic Frontier, revised edition        1
# Mind and Morals: Essays on Ethics and Cognitive Science                                1
# ROBOT RACE (MICRO ADV 6)                                                               1
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
final_df.shape
# Out:
# (1031136, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031136 entries, 0 to 1031135
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   User-ID              1031136 non-null  int64
#  1   ISBN                 1031136 non-null  object
#  2   Book-Rating          1031136 non-null  int64
#  3   Book-Title           1031136 non-null  object
#  4   Book-Author          1031135 non-null  object
#  5   Year-Of-Publication  1031136 non-null  object
#  6   Publisher            1031134 non-null  object
#  7   Image-URL-S          1031136 non-null  object
#  8   Image-URL-M          1031136 non-null  object
#  9   Image-URL-L          1031132 non-null  object
#  10  Location             1031136 non-null  object
#  11  Age                  753301 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 102.3+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
final_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
sns.heatmap(final_df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.savefig("visualizing_missing_data_with_heatmap_Seaborn_Python.png", dpi=100)

# %%
# Missing Values/Null Values Count
final_df.isnull().sum()
# Out:
# User-ID                     0
# ISBN                        0
# Book-Rating                 0
# Book-Title                  0
# Book-Author                 1
# Year-Of-Publication         0
# Publisher                   2
# Image-URL-S                 0
# Image-URL-M                 0
# Image-URL-L                 4
# Location                    0
# Age                    277835
# dtype: int64

# %%
#book author column has one null values 
final_df['Book-Author'].isnull().sum()
# Out:
# 1

# %%
#finding that rows in which the author name is nan so that we can get book name and find the author of the book
df_null_book_author=final_df[final_df['Book-Author'].isnull()]

# %%
#checking the rows which has nan value in book author
df_null_book_author
# Out:
#         User-ID        ISBN  Book-Rating  \
# 486486    98647  9627982032            8
#
#                                                Book-Title Book-Author  \
# 486486  The Credit Suisse Guide to Managing Your Perso...         NaN
#
#        Year-Of-Publication                       Publisher  \
# 486486                1995  Edinburgh Financial Publishing
#
#                                               Image-URL-S  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-M  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-L  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                             Location   Age
# 486486  selayang, selangor, malaysia  26.0

# %%
#filling the nan value with the author name after finding its name from web
final_df['Book-Author'].fillna('David Tait',inplace=True)

# %%
#checking the rows whether the name has been successfully filled or not.
final_df[final_df['ISBN']=='9627982032']
# Out:
#         User-ID        ISBN  Book-Rating  \
# 486486    98647  9627982032            8
#
#                                                Book-Title Book-Author  \
# 486486  The Credit Suisse Guide to Managing Your Perso...  David Tait
#
#        Year-Of-Publication                       Publisher  \
# 486486                1995  Edinburgh Financial Publishing
#
#                                               Image-URL-S  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-M  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                                               Image-URL-L  \
# 486486  http://images.amazon.com/images/P/9627982032.0...
#
#                             Location   Age
# 486486  selayang, selangor, malaysia  26.0

# %%
#checking the number of null values in publisher column found it to be 2
final_df['Publisher'].isnull().sum()
# Out:
# 2

# %%
#finding those rows from the final datasets which has null valus and also to find book and author name so that publisher can be found.
df_null_publisher=final_df[final_df['Publisher'].isnull()]
df_null_publisher
# Out:
#       User-ID        ISBN  Book-Rating       Book-Title      Book-Author  \
# 9777    98391  193169656X            9      Tyrant Moon  Elaine Corvidae
# 9786    98391  1931696993            9  Finders Keepers  Linnea Sinclair
#
#      Year-Of-Publication Publisher  \
# 9777                2002       NaN
# 9786                2001       NaN
#
#                                             Image-URL-S  \
# 9777  http://images.amazon.com/images/P/193169656X.0...
# 9786  http://images.amazon.com/images/P/1931696993.0...
#
#                                             Image-URL-M  \
# 9777  http://images.amazon.com/images/P/193169656X.0...
# 9786  http://images.amazon.com/images/P/1931696993.0...
#
#                                             Image-URL-L              Location  \
# 9777  http://images.amazon.com/images/P/193169656X.0...  morrow, georgia, usa
# 9786  http://images.amazon.com/images/P/1931696993.0...  morrow, georgia, usa
#
#        Age
# 9777  52.0
# 9786  52.0

# %%
#filling the nan values of publisher manually searching the name from web
final_df['Publisher'].fillna('Novelbooks Inc',inplace=True)

# %%
#checking whether the nan has been properly filled or not
final_df[final_df['ISBN']=='193169656X']
# Out:
#       User-ID        ISBN  Book-Rating   Book-Title      Book-Author  \
# 9777    98391  193169656X            9  Tyrant Moon  Elaine Corvidae
#
#      Year-Of-Publication       Publisher  \
# 9777                2002  Novelbooks Inc
#
#                                             Image-URL-S  \
# 9777  http://images.amazon.com/images/P/193169656X.0...
#
#                                             Image-URL-M  \
# 9777  http://images.amazon.com/images/P/193169656X.0...
#
#                                             Image-URL-L              Location  \
# 9777  http://images.amazon.com/images/P/193169656X.0...  morrow, georgia, usa
#
#        Age
# 9777  52.0

# %%
##checking whether the nan has been properly filled or not
final_df[final_df['ISBN']=='1931696993']
# Out:
#       User-ID        ISBN  Book-Rating       Book-Title      Book-Author  \
# 9786    98391  1931696993            9  Finders Keepers  Linnea Sinclair
#
#      Year-Of-Publication       Publisher  \
# 9786                2001  Novelbooks Inc
#
#                                             Image-URL-S  \
# 9786  http://images.amazon.com/images/P/1931696993.0...
#
#                                             Image-URL-M  \
# 9786  http://images.amazon.com/images/P/1931696993.0...
#
#                                             Image-URL-L              Location  \
# 9786  http://images.amazon.com/images/P/1931696993.0...  morrow, georgia, usa
#
#        Age
# 9786  52.0

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **The final dataset is acombination of user,books and rating datasets,all these datasets have different informations.Lets look at each datasets individually.**
#
# **users.**
#
# Note that user IDs (User-ID) have been anonymized and map to integers. Demographic data is provided (Location, Age) if available. Otherwise, these fields contain NULL values.Age of most of the users are not present.
#
# **Books**
#
# are identified by their respective ISBN. Invalid ISBNs have already been removed from the dataset. Moreover, some content-based information is given (Book-Title, Book-Author, Year-Of-Publication, Publisher), obtained from Amazon Web Services. Note that in the case of several authors, only the first is provided. URLs linking to cover images are also given, appearing in three different flavors (Image-URL-S, Image-URL-M, Image-URL-L), i.e., small, medium, large. These URLs point to the Amazon website.
#
# **Ratings**
#
# Contains the book rating information. Ratings (Book-Rating) are either explicit, expressed on a scale from 1-10 (higher values denoting higher appreciation), or implicit, expressed by 0.
#
#
#
# *  There are three null values each in
#
#  Book-Author
# Year-Of-Publication
# Publisher
# Image-URL-S
# Image-URL-M
# Image-URL-L
#
# we must find the ids of these columns then we can fill it manually or either drop the corresponding rows.
#
# *   Most of the features are object or string type and age column has lots of missing values.
#
#
#
# *   There was one row in which the author name was missing we filled the author name manually.
# *   There was also two rows in which the publisher name was missing we filled it manually.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
final_df.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating', 'Book-Title', 'Book-Author',
#        'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M',
#        'Image-URL-L', 'Location', 'Age'],
#       dtype='object')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031136 entries, 0 to 1031135
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   User-ID              1031136 non-null  int64
#  1   ISBN                 1031136 non-null  object
#  2   Book-Rating          1031136 non-null  int64
#  3   Book-Title           1031136 non-null  object
#  4   Book-Author          1031136 non-null  object
#  5   Year-Of-Publication  1031136 non-null  object
#  6   Publisher            1031136 non-null  object
#  7   Image-URL-S          1031136 non-null  object
#  8   Image-URL-M          1031136 non-null  object
#  9   Image-URL-L          1031132 non-null  object
#  10  Location             1031136 non-null  object
#  11  Age                  753301 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 134.5+ MB

# %%
# Dataset Describe
final_df.describe()
# Out:
#             User-ID   Book-Rating            Age
# count  1.031136e+06  1.031136e+06  753301.000000
# mean   1.405945e+05  2.839051e+00      37.397648
# std    8.052466e+04  3.854157e+00      14.098254
# min    2.000000e+00  0.000000e+00       0.000000
# 25%    7.041500e+04  0.000000e+00      28.000000
# 50%    1.412100e+05  0.000000e+00      35.000000
# 75%    2.114260e+05  7.000000e+00      45.000000
# max    2.788540e+05  1.000000e+01     244.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **In the final_df we have the following feature variables.**
#
#
#
# *
# User-ID (unique for each user)
# *  Location (contains city, state and country separated by commas)
#
#
#
# *   Age
# *   ISBN (unique for each book)
#
#
# *  Book-Title
# *  Book-Author
#
#
# *   Year-Of-Publication
# *   Publisher
#
#
# *   Image-URL-S
# *   Image-URL-M
#
#
# *   Image-URL-L
# *   Book-Rating
#
#
#
# > Most of the features are object or string datatype except id and rating which is integer type.
#
#
#
#
#
#
# > The age column has lots of null values and it also contains outliers looking at the describe table we can observe the mean is 37 and it has large value of standard deviation i.e.15.Also we can observe the max and min value of age is 244 and 0 which is not possible.
#
#
#
# > The ratings are very unevenly distributed, and the vast majority of ratings are 0.Ratings are either explicit, expressed on a scale from 1–10 higher values denoting higher appreciation, or implicit, expressed by 0.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in final_df.columns:
  print(' ')
  print('='*21)
  print('The value counts of the columns {}'.format(i),'is')
  print(final_df[i].value_counts())
  print(' ')
# Out:
#
# ...
# The value counts of the columns User-ID is
# 11676     11144
# 198711     6456
# 153662     5814
# 98391      5779
# 35859      5646
#           ...
# 4002          1
# 78202         1
# 4016          1
# 55986         1
# 276660        1
# Name: User-ID, Length: 92106, dtype: int64
#
#
# ...
# The value counts of the columns ISBN is
# 0971880107    2502
# 0316666343    1295
# 0385504209     883
# 0060928336     732
# 0312195516     723
#               ...
# 0671878859       1
# 0689870574       1
# 0743488229       1
# 0812514319       1
# 0583307841       1
# Name: ISBN, Length: 270151, dtype: int64
#
#
# ...
# The value counts of the columns Book-Rating is
# 0     647294
# 8      91804
# 10     71225
# 7      66402
# 9      60778
# 5      45355
# 6      31687
# 4       7617
# 3       5118
# 2       2375
# 1       1481
# Name: Book-Rating, dtype: int64
#
#
# ...
# The value counts of the columns Book-Title is
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# Data Munging, commonly referred to as Data Wrangling, is the cleaning and transforming of one type of data to another type to make it more appropriate into a processed format. Data wrangling involves processing the data in various formats and analyzes and get them to be used with another set of data and bringing them together into valuable insights. It further includes data aggregation, data visualization, and training statistical models for prediction. data wrangling is one of the most important steps of the data science process. The quality of data analysis is only as good as the quality of data itself, so it is very important to maintain data quality.

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#checking for duplicate values
final_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is not a single duplicate values present in our dataset.

# %%
#checking the null values in the location column
final_df['Location'].isnull().sum()
# Out:
# 0

# %%
#Now lets check the location column of the dataset
for i,j in enumerate(final_df['Location'][441].split()):
  print(i,j)
# Out:
# 0 strafford,
# 1 missouri,
# 2 usa

# %% [markdown]
# We can clearly see that location column has three entries city,state and country.We will write a code to make a new column named country in the dataset and it will only contain the name of country of the users.

# %%
#function to fetch the entry from a list which is at the index 2 or 3
def country_name(x):
  a=[]
  for i,j in enumerate(x.split()):
    if i==2 or i==3:
      a.append(j)
  return a

# %%
#validating the function working
country_name(final_df['Location'][441])
# Out:
# ['usa']

# %%
#fetching the country name of each users from column locations
#step 1:- changing the strings into list of words then fetching only that name which is at either index 2 or index 3
final_df['country']=final_df['Location'].apply(lambda x: country_name(x))

# %% [markdown]
# The above code gave us the list of country and states as well now we wiil make a function which will fetch the name of country out of it

# %%
#function to fetch the country name from lists of state and country name 
def country_list(x):
  a=[]
  if len(x)==2:
    for i,j in enumerate(x):
      if i==1:
        a.append(j)
    return a
  else:
    return x

# %%
#aplying function to each rows of country
final_df['country']=final_df['country'].apply(lambda x:country_list(x))

# %%
final_df.sample(10)
# Out:
#          User-ID        ISBN  Book-Rating  \
# 400281     63714  1857025024            9
# 280802     88283  038548237X            8
# 684094    261603  0553296124            0
# 748720    106369  0553279912            8
# 1010457    35527  0736908315            5
# 1006983   229712  0285636391            0
# 1026248   255887  3442721326            7
# 948357    154150  0553375407            0
# 169947    231210  0345336615            0
# 680891    158318  3404242254            0
#
#                                                 Book-Title  \
# 400281       Longitude Uk Edition True Story of a Lone Gen
# 280802                              The Mistress of Spices
# 684094   Heir to the Empire (Star Wars: The Thrawn Tril...
# 748720   A Is for Alibi (Kinsey Millhone Mysteries (Pap...
# 1010457                   Minute Meditations for Busy Moms
# 1006983  Nostradamus: The Final Prophecies: A Revolutio...
# 1026248                                  Hemingways Stuhl.
# ...

# %%
#dropping the column location
final_df.drop(['Location'],axis=1,inplace=True)

# %%
#finding the top ten country which has large no of users.
final_df['country'].apply(lambda x: str(x)).value_counts()[0:10]
# Out:
# ['usa']          711673
# ['canada']        87608
# ['kingdom']       28377
# ['germany']       26680
# []                18303
# ['spain']         13378
# ['york,']         11751
# ['n/a']           11177
# ['australia']     11164
# ['france']         7646
# Name: country, dtype: int64

# %%
#creating a seperate dataframe for urls which can be used during deployment
df_url=final_df[['Image-URL-S','Image-URL-M','Image-URL-L']]

# %%
df_url.head()
# Out:
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/0812533550.0...
# 3  http://images.amazon.com/images/P/0679745580.0...
# 4  http://images.amazon.com/images/P/0060173289.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/0812533550.0...
# 3  http://images.amazon.com/images/P/0679745580.0...
# 4  http://images.amazon.com/images/P/0060173289.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/0812533550.0...
# 3  http://images.amazon.com/images/P/0679745580.0...
# 4  http://images.amazon.com/images/P/0060173289.0...

# %%
#now dropping the urls column which is not relevant for recommendation system
final_df.drop(['Image-URL-S','Image-URL-M','Image-URL-L'],axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031136 entries, 0 to 1031135
# Data columns (total 9 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   User-ID              1031136 non-null  int64
#  1   ISBN                 1031136 non-null  object
#  2   Book-Rating          1031136 non-null  int64
#  3   Book-Title           1031136 non-null  object
#  4   Book-Author          1031136 non-null  object
#  5   Year-Of-Publication  1031136 non-null  object
#  6   Publisher            1031136 non-null  object
#  7   Age                  753301 non-null   float64
#  8   country              1031136 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 110.9+ MB

# %%
# Checking null values in publisher
final_df[final_df['Publisher'].isna()]
# Out:
# Empty DataFrame
# Columns: [User-ID, ISBN, Book-Rating, Book-Title, Book-Author, Year-Of-Publication, Publisher, Age, country]
# Index: []

# %%
#insepcting the values in year of publication
final_df['Year-Of-Publication'].unique()
# Out:
# array(['2002', '1986', '1994', '1996', '1998', '2001', '1987', '1984',
#        '1997', '1970', '1978', '1993', '1989', '1995', '1990', '1992',
#        '1950', '1991', '1999', '1954', '1988', '2003', '2004', '2000',
#        '1983', '1985', '1982', '1956', '1979', '1975', '0', '1976',
#        '1981', '1977', '1980', '1974', '1957', '1958', '1960', '1963',
#        '1969', '1972', '1961', '1971', '1953', '1968', '1973', '1967',
#        '1962', '1937', '1959', '1955', '1946', '2005', '1945', '1965',
#        '1964', '1927', '2020', '2050', '1920', '1966', '1952', '1930',
#        '1940', '1942', '1947', '1925', '1948', '1923', '2030', '1951',
#        '2021', '1941', '1932', '2011', '1901', '2038', '1929', '1943',
#        '1936', '1928', '1939', '1944', '1938', '1902', '1900', '1911',
#        '1949', '1906', '1806', '1933', '1935', '1926', '1922', '1897',
#        '2026', '2006', '2037', '1924', '1921', '2024', '1378', '2008',
# ...

# %% [markdown]
# Now we can clearly see that the year of publications has some irrelevant entries like DK Publishing and Gallimard.Also there are 0,2037,2030 like values which is not possible so we will trace those rows and will try to fill with proper values.

# %%
#finding those rows in which the year of publication is DK Publishing Inc
final_df[final_df['Year-Of-Publication']=='DK Publishing Inc']
# Out:
#         User-ID        ISBN  Book-Rating  \
# 85425    130571  0789466953            0
# 346284   227771  078946697X            7
# 594299   169663  078946697X            0
#
#                                                Book-Title Book-Author  \
# 85425   DK Readers: Creating the X-Men, How Comic Book...        2000
# 346284  DK Readers: Creating the X-Men, How It All Beg...        2000
# 594299  DK Readers: Creating the X-Men, How It All Beg...        2000
#
#        Year-Of-Publication                                          Publisher  \
# 85425    DK Publishing Inc  http://images.amazon.com/images/P/0789466953.0...
# 346284   DK Publishing Inc  http://images.amazon.com/images/P/078946697X.0...
# 594299   DK Publishing Inc  http://images.amazon.com/images/P/078946697X.0...
#
#          Age   country
# 85425    NaN     [usa]
# 346284  19.0  [israel]
# 594299   NaN     [usa]

# %%
#replacing the DK Publishing Inc with 2000 in year-of-publication column
final_df['Year-Of-Publication'].replace('DK Publishing Inc','2000',inplace=True)

# %%
#replacing book-author where it is 2000 with correct name
final_df['Book-Author'].replace('2000','Buckley Jr. James',inplace=True)

# %%
#replacing url link given in publisher with correct publisher name
final_df['Publisher'].replace('http://images.amazon.com/images/P/0789466953.01.THUMBZZZ.jpg'	,'DK Publishing Inc',inplace=True)
final_df['Publisher'].replace('http://images.amazon.com/images/P/078946697X.01.THUMBZZZ.jpg'	,'DK Publishing Inc',inplace=True)

# %%
#checking the transformed rows
final_df[final_df['ISBN']=='078946697X']
# Out:
#         User-ID        ISBN  Book-Rating  \
# 346284   227771  078946697X            7
# 594299   169663  078946697X            0
#
#                                                Book-Title        Book-Author  \
# 346284  DK Readers: Creating the X-Men, How It All Beg...  Buckley Jr. James
# 594299  DK Readers: Creating the X-Men, How It All Beg...  Buckley Jr. James
#
#        Year-Of-Publication          Publisher   Age   country
# 346284                2000  DK Publishing Inc  19.0  [israel]
# 594299                2000  DK Publishing Inc   NaN     [usa]

# %%
#finding those rows in which year of publication is Gallimard
final_df[final_df['Year-Of-Publication']=='Gallimard']
# Out:
#         User-ID        ISBN  Book-Rating  \
# 402556   137190  2070426769            0
#
#                                                Book-Title Book-Author  \
# 402556  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...        2003
#
#        Year-Of-Publication                                          Publisher  \
# 402556           Gallimard  http://images.amazon.com/images/P/2070426769.0...
#
#          Age   country
# 402556  31.0  [france]

# %%
#correcting all the wrong entries in the above rows
final_df['Year-Of-Publication'].replace('Gallimard','2003',inplace=True)
final_df['Publisher'].replace('http://images.amazon.com/images/P/2070426769.01.THUMBZZZ.jpg','Gallimard',inplace=True)
final_df['Book-Author'].replace('2003','J.M.G. Le Clézio',inplace=True)

# %%
#checking the transformed rows
final_df[final_df['ISBN']=='2070426769']
# Out:
#         User-ID        ISBN  Book-Rating  \
# 402556   137190  2070426769            0
#
#                                                Book-Title       Book-Author  \
# 402556  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...  J.M.G. Le Clézio
#
#        Year-Of-Publication  Publisher   Age   country
# 402556                2003  Gallimard  31.0  [france]

# %%
#finding those rows in which year of publication is 0
#pd.set_option('display.max_rows', None)
#final_df[final_df['Year-Of-Publication']==0]

# %%
#there are 9879 books whose year of publications is 0
final_df[final_df['Year-Of-Publication']==0].shape[0]
# Out:
# 0

# %%
#checking all the unique authors and their name correct spelled or not
#pd.set_option('display.max_rows', None)
#for i in final_df['Book-Author'].unique():
  #print(i)

# %%
#finding the total number of unique authors
len(final_df['Book-Author'].unique())
# Out:
# 101589

# %%
#finding top ten authors who have written many books
pd.set_option('display.max_rows', None)
final_df['Book-Author'].value_counts()[0:10]
# Out:
# Stephen King          10053
# Nora Roberts           8429
# John Grisham           6010
# James Patterson        5845
# Mary Higgins Clark     4777
# Dean R. Koontz         4313
# Tom Clancy             4036
# Danielle Steel         3726
# Sue Grafton            3457
# Janet Evanovich        3350
# Name: Book-Author, dtype: int64

# %%
#finding the name of unique books present inside the dataframe
pd.set_option('display.max_rows', None)
pd.DataFrame(final_df['Book-Title'].unique())

# %%
#number of unique books in datasets
len(final_df['Book-Title'].unique())
# Out:
# 241071

# %%
#most famous books and their frequency in the datasets
final_df['Book-Title'].value_counts()[1:10]
# Out:
# The Lovely Bones: A Novel                          1295
# The Da Vinci Code                                   898
# A Painted House                                     838
# The Nanny Diaries: A Novel                          828
# Bridget Jones's Diary                               815
# The Secret Life of Bees                             774
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     740
# The Red Tent (Bestselling Backlist)                 723
# Angels &amp; Demons                                 670
# Name: Book-Title, dtype: int64

# %%
#looking at the book named 'The Lovely Bones: A Novel' and checking its duplicacy,we can clearly see these books have different user id
final_df[final_df['Book-Title']=='The Lovely Bones: A Novel']

# %%
# Checking  for  null value in book author
final_df[final_df['Book-Author'].isna()]

# %%
final_df.head(2)

# %%
# !pip install ydata-profiling

# %%
from pandas_profiling import ProfileReport
prof= ProfileReport(final_df)
prof.to_file(output_file='output.html')

# %%
html=pd.read_html('/content/output.html')

# %%
html

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **1.**   First we checked for duplicated rows inside the final dataframe and found there was not a single duplicate rows present inside the dataframe.
#
# ***2. ***  Then we checked in location column which consists of city,state and country name,written a functions to fetch the country name from the column.Then we drop the location column.
#
#
#
# **3.**   Then find the top ten countries which has large number of users.
#
# ***4. ***Then created the seperated dataframe for urls which can be used later for deployment and finally dropped the image urls column which is not relevant for recommendations.
#
# **5.** Then we cheked for year of publication column in which we found there are many(9879) rows in which the year of publication is 0 and one of the rows has nan values.
#
# **6.**There are 45477 unique authors and 99451 unique books in the datasets.
#
# **7.** We also find that the books title are present in different languages.
#
# **8.**There were some rows in the datasets in which the there were wrong items given,we identified those rows and corrected them with our domain knowledge.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#finding the top ten authors which occured in the datasets frequently
No_books_by_author=final_df['Book-Author'].value_counts().reset_index()
No_books_by_author[0:11]
# Out:
#                  index  Book-Author
# 0         Stephen King        10053
# 1         Nora Roberts         8429
# 2         John Grisham         6010
# 3      James Patterson         5845
# 4   Mary Higgins Clark         4777
# 5       Dean R. Koontz         4313
# 6           Tom Clancy         4036
# 7       Danielle Steel         3726
# 8          Sue Grafton         3457
# 9      Janet Evanovich         3350
# 10           Anne Rice         3030

# %%
#changing the column name
No_books_by_author.rename(columns={'index':'author_name','Book-Author':'count_books'},inplace=True)

# %%
No_books_by_author[0:11]

# %%
#bivariate analysis through bartplot which gives most  no of books users interested in
plt.figure(figsize=(12,10))
sns.barplot(x='author_name',y='count_books',data=No_books_by_author[:6])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x-axis and a numerical column for the y-axis.I wanted to see the authors which has most users in the datasets also the number of users.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most of the users like to read the books written by these top ten authors.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# **if the business is a book publisher, this information can be useful in identifying which authors to sign for future publications or which authors to prioritize in terms of marketing efforts. On the other hand, if the business is a bookstore, this information can be useful in determining which authors to stock more of or which authors to feature in promotions.**

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#from the above code we find that the Stephen King is the most popular authors among the users,Now we are going to find which book of stephen king is most popular
Steph_king_pop_books=final_df[final_df['Book-Author']=='Stephen King'].groupby('Book-Title').count().sort_values('User-ID',ascending=False).reset_index()[0:11]

# %%
#bivariate analysis through barplot which tells the most famous books of Stephen King among users
plt.figure(figsize=(18,10))
sns.barplot(x='Book-Title',y='User-ID',data=Steph_king_pop_books[0:6])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. It can also be understood as a visualization of the group by action. To use this plot we choose a categorical column for the x-axis and a numerical column for the y-axis.We wanted to observe which book of Stephen King is more popular among users.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights found from this chart are the most popular books written by Stephen King, which can be useful for a business in the book industry, such as a publisher, bookstore, or online retailer. This information can help inform decisions about which books to stock or feature in promotions, as well as which books to potentially acquire the rights to publish.Dreamctcher,Misey,Dolores Claiborne are some of the famous books of Stephen King.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *** It is important to note that the business impact of this information depends on the specific business goals and context. For example, if the business primarily focuses on selling books in a specific genre, this information may not be as relevant if the popular Stephen King books are not in that genre. Additionally, if the business is a publisher, the popularity of Stephen King books may not be relevant if the business is not interested in acquiring the rights to publish books in that genre or from that author.***

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#creating a new dataframe from original which has two columns book rating and book author and finding the name of author which has highest rating
author_rating_df=final_df[['Book-Rating','Book-Author']].groupby('Book-Author').sum('Book-Rating').reset_index().sort_values('Book-Rating',ascending=False)[0:6]

# %%
#checking the created dataframe,and top authors with rating
author_rating_df

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Book-Author',y='Book-Rating',data=author_rating_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The specific chart was chosen to visualize the relationship between the book ratings and authors. By aggregating the book ratings by author and sorting them in descending order, we can gain insight into which authors are most highly regarded by readers in terms of the quality of their books.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights gained from this chart are which authors have the highest sum of book ratings and are therefore perceived by readers as producing high-quality books. This information can be useful for a business in the book industry, such as a publisher or online retailer, as it can help inform decisions about which authors to potentially acquire the rights to publish or which books to feature in promotions.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **it is important to note that the business impact of this information depends on the specific business goals and context. For example, if the business primarily focuses on selling books in a specific genre, this information may not be as relevant if the highly-rated authors are not in that genre. Additionally, if the business is a publisher, the book ratings of authors may not be the only factor to consider when deciding whether to acquire the rights to publish books from a specific author.**

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#creating new dataframe which only contains book name and their ratings
books_rating_df=final_df[['Book-Title','Book-Rating']].groupby('Book-Title').sum('Book-Rating').sort_values(by='Book-Rating',ascending=False).reset_index()[0:6]

# %%
books_rating_df

# %%
#top 15 books which got most of the ratings by users
plt.figure(figsize=(12,10))
sns.barplot(x='Book-Rating',y='Book-Title',data=books_rating_df[0:15])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *** It is creating a horizontal bar plot using Seaborn library, with the top 15 books ranked by the sum of their book ratings as the x and y-axis variables, respectively.The specific chart was chosen to visualize the relationship between the book ratings and titles. By aggregating the book ratings by title and sorting them in descending order, we can gain insight into which books are most highly regarded by readers in terms of their quality.***

# %% [markdown]
# **The insights gained from this chart are which books have the highest sum of book ratings and are therefore perceived by readers as high-quality. This information can be useful for a business in the book industry, such as a publisher or online retailer, as it can help inform decisions about which books to potentially acquire the rights to publish or which books to feature in promotions.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Regarding negative growth, there could be potential negative impacts on certain authors or books that did not make it to the top of the list. If a business solely focuses on promoting and selling books that have high ratings, it could lead to neglecting authors and books that may still have potential for growth or appeal to niche markets. Additionally, if a business focuses too heavily on promoting the same highly-rated books over and over, it could lead to oversaturation and a decrease in interest from readers over time. Therefore, it's important to strike a balance between promoting highly-rated books and giving other authors and books a chance to be discovered by readers.**

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#creating a new dataframe which only contains book name, author name and ratings by users
books_author_rating_df=final_df[['Book-Title','Book-Author','Book-Rating']]
books_author_rating_df.head()

# %%
#now finding the combinations of books and authors which habve got the hioghest ratings
books_author_rating_df=books_author_rating_df.groupby(['Book-Title','Book-Author']).sum('Book-Rating').sort_values(by='Book-Rating',ascending=False).reset_index()[0:6]

# %%
#creating a new column which contains the name of book and its author
books_author_rating_df['books+author+rating']=books_author_rating_df['Book-Title']+'--  '+books_author_rating_df['Book-Author']

# %%
#final dataframe with book name author name and corresponding ratings only top
books_author_rating_df.head()

# %%
plt.figure(figsize=(16,6))
sns.barplot(x='Book-Rating',y='books+author+rating',data=books_author_rating_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **It is creating a horizontal bar plot using Seaborn library, with the top 6 books ranked by the sum of their book ratings, along with their respective authors, as the y-axis variable and the book ratings as the x-axis variable.The specific chart was chosen to visualize the relationship between book ratings and the authors of the books with the highest ratings. By aggregating the book ratings by author and book title and sorting them in descending order, we can gain insight into which authors are most highly regarded by readers in terms of the quality of their books.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights gained from this chart are which authors have produced the highest-rated books and are therefore perceived by readers as high-quality authors. This information can be useful for a business in the book industry, such as a publisher or online retailer, as it can help inform decisions about which authors to potentially work with or which books to feature in promotions.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Regarding negative growth, there could be potential negative impacts on certain authors or books that did not make it to the top of the list. If a business solely focuses on promoting and working with highly-rated authors, it could lead to neglecting other authors who may still have potential for growth or appeal to niche markets. Additionally, if a business focuses too heavily on promoting the same highly-rated authors over and over, it could lead to oversaturation and a decrease in interest from readers over time. Therefore, it's important to strike a balance between promoting highly-rated authors and giving other authors a chance to be discovered by readers.**

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#creating a new dataframe which counts the no. of user id for a particular book
top_books_selling_df=final_df[['Book-Title','User-ID']].groupby('Book-Title').count().sort_values(by='User-ID',ascending=False).reset_index()

# %%
#top 5 books by number of user id
top_books_selling_df[0:6]

# %%
final_df[final_df['Book-Title']=='Wild Animus']

# %%
#plotting the barplot for the same
plt.figure(figsize=(12,10))
sns.barplot(x='User-ID',y='Book-Title',data=top_books_selling_df[0:15])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **It is creating a horizontal bar plot using Seaborn library, with the top 15 books ranked by the number of times they have been sold (i.e., the number of times they appear in the dataset), as the y-axis variable and the count of book sales as the x-axis variable.**
#
# ***The specific chart was chosen to visualize the popularity of books based on the number of times they have been sold. This information can be useful for a business in the book industry to help inform decisions about which books to stock and which books to promote. ***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights gained from this chart are which books are most popular among readers and are therefore more likely to generate sales. This information can be useful for a business to prioritize the promotion and stocking of these books to increase sales.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **However, it's important to note that the popularity of a book does not necessarily guarantee its quality or long-term success. In some cases, books may be popular due to marketing efforts, current events, or other factors that are not directly related to the book's content or quality.**

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Chart - 6 visualization code
#counting the frequency of user id
user_id_count=final_df['User-ID'].value_counts().reset_index()
user_id_count.rename(columns={'index':'id','User-ID':'counts'},inplace=True)
user_id_count.head()

# %%
#visualisation through barplot
plt.figure(figsize=(12,10))
sns.barplot(x='id',y='counts',data=user_id_count[:5])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A bar chart to visualize the count of books read by the top 5 users with the most book ratings**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights gained from this chart could be used to identify highly engaged and active users of the platform, which could be leveraged for targeted marketing campaigns or for personalized recommendations to these users.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **However, without more context or specific business goals, it is difficult to determine if these insights would lead to positive or negative growth.**

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#finding the top ten country which has large no of users.
top_users_country=final_df['country'].apply(lambda x: str(x)).value_counts()[0:10].reset_index()
top_users_country.rename(columns={'index':'country_name'},inplace=True)
top_users_country.rename(columns={'country':'no_of_users'},inplace=True)
top_users_country.head()

# %%
#plotting the graph between no of users and country name
plt.figure(figsize=(14,6))
sns.barplot(x='no_of_users',y='country_name',data=top_users_country)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **As we were doing bivariate analysis in which we wanted to know the number of users from each country,hence we used barplot.The chart was selected to visualize the distribution of users across different countries. The insights gained from the chart can help identify the countries with the highest number of users and prioritize business efforts in those countries.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **For example, the chart shows that the majority of users are from the USA, followed by Canada and the UK. This can help businesses tailor their marketing strategies to target these countries specifically and increase user engagement.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **As for negative growth, there are no immediate insights from this chart that would indicate negative growth. However, it's important to note that this chart only shows the top 10 countries and there may be other countries with a smaller number of users that are experiencing negative growth.**

# %% [markdown]
# #### Chart - 9

# %%
final_df.head()

# %%
# Chart - 9 visualization code
plt.figure(figsize=(16,4))
sns.boxplot(x='Book-Rating',y='Age',data=final_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The box plot is a useful visualization for showing the distribution of a variable and identifying potential outliers. By using a box plot to compare the distribution of book ratings across different age groups, we can gain insights into how age may impact book ratings.**
#
# **The specific chart was likely chosen because it allows us to examine the distribution of book ratings across different age groups, which can help us understand whether there are age-related trends or biases in book ratings.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **From the chart, we can see that the median book rating is slightly higher for older readers (around 50 years old and above) compared to younger readers (below 40 years old). Additionally, we can see that there are some outliers in the data, particularly for younger readers who give very high or very low book ratings.**
#
# These insights may suggest that age could be a factor in book ratings, and that younger readers may have more varied or extreme preferences compared to older readers. However, further analysis would be needed to confirm these hypotheses and investigate other potential factors that may influence book ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#categorising the age column and renaming as children,teens,youth,adults and elderly according to their ages.
def age_group(age):
  ''' 
  defines the age group of users
  '''
  if age<13:
    x='Children'
  elif age>=13 and age<18:
    x='Teens'
  elif age>=18 and age<36:
    x='Youth'
  elif age>=36 and age<56:
    x='Middle aged adults'
  else:
    x='Elderly'
  return x

# %%
#categorising the age into children,teens,youth,middle aged adults and elderly for each rows
final_df['Age_group']=final_df['Age'].apply(lambda x: age_group(x))

# %%
final_df.head()

# %%
#Age distribution of users
sns.countplot(final_df['Age_group'],palette='Set2')

# %%
fig=plt.figure(figsize=(20,14))
i=1
for group  in ['Children','Teens','Youth','Middle aged adults','Elderly']:
  age_df=final_df.loc[final_df['Age_group']==group].groupby(['Book-Title']).agg(No_of_users=('User-ID','nunique'),total_rating=('Book-Rating','sum')).reset_index() 
  plt.subplot(5,2,i)
  age_df.sort_values(by='No_of_users',ascending=False,inplace=True)
  sns.barplot(x='No_of_users',y='Book-Title',palette='Paired',data=age_df.head(5))
  plt.title('Top 5 Popular books among  {}'.format(group),size=16)
  i+=1
  plt.subplot(5,2,i)
  age_df.sort_values(by='total_rating',ascending=False,inplace=True)
  sns.barplot(x='total_rating',y='Book-Title',palette='Set2',data=age_df.head(5))
  plt.title('Top rated books by {} '.format(group),size=16)
  i+=1
  
plt.tight_layout()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I wanted to see which age group have more interests in reading books hence we use barplot for the same.The charts display the top 5 popular  books and top rated books among different age groups such as Children, Teens, Youth, Middle aged adults, and Elderly.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insights gained from these charts are that the book preferences and ratings vary among different age groups. For example, Children tend to prefer books like Harry Potter, while Youth prefer books like The Da Vinci Code. Similarly, Middle aged adults tend to prefer books like The Lovely Bones, while Elderly tend to prefer books like The Bridges of Madison County.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **These insights can help businesses to target their marketing strategies towards specific age groups and offer personalized recommendations based on their preferences. For example, a bookstore can promote books like Harry Potter to children and books like The Lovely Bones to middle-aged adults.**

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(16,4))
sns.distplot(final_df['Book-Rating'])

# %%
# book ratings
final_df['Book-Rating'].value_counts().reset_index()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I wanted to check the ratings behaviour of users.A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables.The chart is a histogram with a density curve that shows the distribution of book ratings given by the users. The histogram shows that the majority of book ratings are between 5 and 10, indicating that most users have given positive ratings to the books they have read. The density curve is also skewed towards the right, which means that the distribution is positively skewed.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Ratings (Book-Rating) are either explicit, expressed on a scale from 1-10 (higher values denoting higher appreciation), or implicit, expressed by 0.We can see for explicit ratings that rating 8 is received by most number of books followed by rating 10. There are 647294 implicitely rated books.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **The insights gained from this chart can help businesses understand the overall satisfaction level of their users with the books they provide. The fact that the majority of the ratings are positive indicates that users are generally happy with the books they are reading. This could have a positive impact on businesses in terms of customer satisfaction, loyalty, and retention.**
#
# **However, there is a potential negative impact as well. The skewness of the distribution towards the positive end may indicate that users are not providing honest or critical feedback on the books they read. This could lead to a false sense of security for businesses, which could eventually lead to a decline in the quality of books being provided if honest feedback is not taken into account.**

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %%
# !pip install -U dataprep

# %%
from dataprep.eda import create_report
create_report(books_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **The "create_report" function generates a comprehensive report on a given dataset, which includes summary statistics, data types, missing values, correlations, and visualizations. The function automatically selects the most appropriate charts and graphs for each variable, depending on the data type and distribution.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **the charts may reveal patterns, trends, outliers, or correlations that are not immediately obvious from the raw data. These insights can inform further analysis and decision-making in various domains, such as marketing, finance, healthcare, and social sciences.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Correlation Heatmap visualization code
#plotting heatmap to observe the correlation between independent variables and dependent variables
plt.figure(figsize=(15,10))
sns.set_palette('OrRd_r')
sns.heatmap(final_df.corr(),annot=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A Heat map is a graphical representation of multivariate data that is structured as a matrix of columns and rows.**
#
# **Heat maps are very useful in describing correlation among several numerical variables, visualizing patterns and anomalies.**
#
# **Correlation is a dimensionless unit that determines the degree to which variables are related. It measures both strength and direction of the linear relationship between variables. Its value lies between 0 and 1, depicting strength. +ve and –ve signs depict direction.**
#
# ***The chart shows a heatmap of the correlation matrix for the numerical variables in the dataset. The darker colors indicate stronger positive correlation while the lighter colors indicate weaker or negative correlation. ***

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **From the chart, we can see that there is a positive correlation between the number of ratings a book receives and the total rating score it has. There is also a weak positive correlation between the year of publication and the age of the user. Additionally, there seems to be no significant correlation between the user's age and the number of ratings they give or the rating score they give.**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
final_df.head()

# %%
# Pair Plot visualization code
# Pair Plot visualization code
fig = plt.figure(figsize = (30,50))
my_palette = {0 : 'orange' , 1 : 'teal'}
sns.pairplot(final_df,palette=my_palette)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **A pair plot is a data visualization that plots pair-wise relationships between all the variables of a dataset. This allows you to better understand the relationships visually, while even layering in additional details (such as by using color). Each variable is plotted both in the rows and columns, showing the relationships between the variables.The diagonal line shows the distribution of values in that variable using a histogram. Each other cell shows the relationship as a scatterplot between the two variables at their intersection.**
#
# **The pairplot is a useful chart to visualize the relationship between multiple variables in a dataset. In this case, the chart shows scatterplots and histograms for each combination of variables in the final_df dataset. The diagonal shows a histogram for each variable.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Insights from the chart can include identifying correlations between variables. For example, we can see a positive correlation between Year-Of-Publication and Book-Rating. This suggests that newer books tend to have higher ratings. We can also see that there is a cluster of Book-Rating scores around 0, which may indicate that users tend to rate books more conservatively (i.e. lower ratings).**
#
# **Overall, this chart can help us gain a better understanding of the relationships between variables in the dataset, which can inform future analysis and modeling.**

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# **Hypothesis testing is a statistical method used to evaluate whether a given hypothesis about a population parameter is supported by the evidence provided by a sample data. The process involves formulating a null hypothesis (H0), which represents the status quo or the commonly accepted belief, and an alternative hypothesis (Ha), which contradicts the null hypothesis and represents the claim to be tested.**
#
# **Next, the researcher selects a level of significance, denoted by α, which represents the probability of rejecting the null hypothesis when it is true. Based on the sample data, a test statistic is calculated and compared to a critical value obtained from the appropriate probability distribution. If the test statistic falls in the rejection region (extreme values unlikely to have occurred by chance under the null hypothesis), the null hypothesis is rejected in favor of the alternative hypothesis, and it is concluded that the claim being tested is supported by the evidence. Otherwise, the null hypothesis is retained, and it is concluded that there is not enough evidence to support the claim.**

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# **To perform a hypothesis test on this dataset, we need to formulate a hypothesis. One possible hypothesis could be:**
#
# **Hypothesis: The average age of book readers in the United States is the same as the average age of book readers in the canada.**
#
# **To test this hypothesis, we can perform a two-sample t-test with a significance level of 0.05.**
#
# **First, we need to split the data into two samples based on the country of the reader, and then calculate the sample means and standard** **deviations of the age data for each group.**
#
# **Then, we can use the t-test to determine if there is a significant difference between the two means. If the p-value is less than 0.05, we** **can reject the null hypothesis and conclude that there is a significant difference in the average age of book readers between the two countries.**

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
import pandas as pd
from scipy.stats import ttest_ind



# Split the data into two samples based on country
us_data = pd.Series(final_df[final_df['country'] == 'usa']['Age'])
canada_data = pd.Series(final_df[final_df['country'] == 'canada']['Age'])

# Calculate the sample means and standard deviations
us_mean = us_data.mean()
canada_mean = canada_data.mean()
us_std = us_data.std()
canada_std = canada_data.std()

# Perform the t-test
t, p = ttest_ind(us_data, canada_data, equal_var=False)

# Print the results
print(f"US Mean Age: {us_mean:.2f}, Standard Deviation: {us_std:.2f}")
print(f"PH Mean Age: {canada_mean:.2f}, Standard Deviation: {canada_std:.2f}")
print(f"T-value: {t:.2f}, p-value: {p:.4f}")
print(us_data)

# %%
final_df['country']=final_df['country'].apply(lambda x: str(x))

# %%
final_df.head()

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %% [markdown]
# **Missing data is defined as the values or data that is not stored (or not present) for some variable/s in the given dataset.In Pandas, usually, missing values are represented by NaN.**

# %% [markdown]
# **Why Is Data Missing From The Dataset**
#
# There can be multiple reasons why certain values are missing from the data.
#
# Some of the reasons are listed below:
#
# Past data might get corrupted due to improper maintenance.
#
# Observations are not recorded for certain fields due to some reasons.
#
# There might be a failure in recording the values due to human error.
#
# The user has not provided the values intentionally.

# %% [markdown]
# **Why Do We Need To Care About Handling Missing Value?**
#
# Many machine learning algorithms fail if the dataset contains missing values. However, algorithms like K-nearest and Naive Bayes support data with missing values.
#
# We may end up building a biased machine learning model which will lead to incorrect results if the missing values are not handled properly.
#
# Missing data can lead to a lack of precision in the statistical analysis.

# %%
# Handling Missing Values & Missing Value Imputation
final_df.isnull().sum()

# %%
final_df.shape

# %% [markdown]
# #Among 1023790 rows the age column has 275943 rows have null values

# %%
#univariate analysis on column age which tells the probablity distribution of the age
plt.figure(figsize=(16,6))
sns.distplot(final_df['Age'])

# %% [markdown]
# **Through dist plot we can clearly see that the age of users are unevenly distributed and find in the range of 0 to 100,we can also observe some outliers.Most of the users are between 30 to 50 years.**

# %%
#univariate analysis on age column through boxplot
plt.figure(figsize=(16,4))
sns.boxplot(final_df['Age'])

# %% [markdown]
# **The Age column is right skewed and has a lot of outliers we can also observe that some of the age is touching 200 and 250 which is not possible also some ages are 0 ,so its better to remove this column as it is not so relevant in our recommendation system.**

# %%
#dropping column age from the dataframe
#final_df.drop(columns='Age',axis=1,inplace=True)

# %%
final_df.head(2)

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# **How To Handle The Missing Data**
#
# ***Deleting the Missing values ***
#
# Deleting the entire row
#
#                       data = data.dropna(axis=0)
#
#   Deleting the entire column
#
#                       data.drop(columns=['education'],inplace=True)
#
#
#   Imputing the Missing Values
#
#                         Replacing With Mean
#                    data['columnname'] = data['columnname'].fillna(data['LoanAmount'].mean())
#
#                 Replacing With Mode
#                 data['columnname1'] = data['columnname1'].fillna(data['columnname1'].mode()[0])
#
#                   Replacing With Median
#                   data['BMI'].fillna(data['BMI'].median(),inplace=True)
#
#                   Replacing with previous value – Forward fill
#                   data['column'].fillna(method=‘ffill')
#
#                   Replacing with next value – Backward fill
#                   data['column'].fillna(method=‘bfill')
#
#                 Impute the Most Frequent Value
#                 from sklearn.impute import SimpleImputer
#                 imputer = SimpleImputer(strategy='most_frequent')
#                 imputer.fit_transform(data['column'])
#
#                 from sklearn.impute import SimpleImputer
#                 imp = SimpleImputer(missing_values=np.nan, strategy='mean')
#                 imp.fit(data['column'])

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# # **What are Outliers?**
#
# An Outlier is an observation in a given dataset that lies far from the rest of the observations. That means an outlier is vastly larger or smaller than the remaining values in the set.An outlier may occur due to the variability in the data, or due to experimental error/human error.
#
# They may indicate an experimental error or heavy skewness in the data(heavy-tailed distribution).

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# **Detecting Outliers**
#
# Below are some of the techniques of detecting outliers
#
# Boxplots
#
# Z-score
#
# Inter Quantile Range(IQR)

# %% [markdown]
# **Detecting outliers using the Z-scores**
#
# any data point whose Z-score falls out of 3rd standard deviation is an outlier.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Below are some of the methods of treating the outliers
#
# Trimming/removing the outlier
#
# Quantile based flooring and capping
#
# Mean/Median imputation
#
# Log transformation.

# %% [markdown]
# ### 3. Categorical Encoding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %% [markdown]
# In machine learning, data splitting is typically done to avoid overfitting. That is an instance where a machine learning model fits its training data too well and fails to reliably fit additional data.
#
# The original data in a machine learning model is typically taken and split into three or four sets. The three sets commonly used are the training set, the dev set and the testing set:

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# Imbalanced data refers to those types of datasets where the target class has an uneven distribution of observations, i.e one class label has a very high number of observations and the other has a very low number of observations.
#
# *Problems with imbalanced data classification *
#
# If we explain it in a very simple manner, the main problem with imbalanced dataset prediction is how accurately are we actually predicting both majority and minority class.It means that the model fails to identify the minority class yet the accuracy score of the model will be high.

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# SMOTE works by utilizing a k-nearest neighbour algorithm to create synthetic data. SMOTE first starts by choosing random data from the minority class, then k-nearest neighbors from the data are set. Synthetic data would then be made between the random data and the randomly selected k-nearest neighbor.
#
# The procedure is repeated enough times until the minority class has the same proportion as the majority class.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# # **Popularity Based Approach**
#
# It is a type of recommendation system which works on the principle of popularity and or anything which is in trend. These systems check about the books which are in trend or are most popular among the users and directly recommend them.
#
# For example, if a product is often purchased by most people then the system will get to know that that product is most popular so for every new user who just signed it, the system will recommend that product to that user also and chances become high that the new user will also purchase that.

# %% [markdown]
# # **Why Is this model relevant?**
#
# The answer to this is the Cold-Start Problem. Cold start is a potential problem in computer-based information systems which involves a degree of automated data modelling. Specifically, it concerns the issue that the system cannot draw any inferences for users or items about which it has not yet gathered sufficient information. The cold start problem is a well known and well researched problem for recommender systems. Recommender systems form a specific type of information filtering (IF) technique that attempts to present information items (e-commerce, films, music, books, news, images, web pages) that are likely of interest to the user. Typically, a recommender system compares the user’s profile to some reference characteristics. These characteristics may be related to item characteristics (content-based filtering) or the user’s social environment and past behavior (collaborative filtering). Depending on the system, the user can be associated with various kinds of interactions: ratings, bookmarks, purchases, likes, number of page visits etc.
#
# **There are three cases of cold start:**
#
# **New community:**
#
#  refers to the start-up of the recommender, when, although a catalogue of items might exist, almost no users are present and the lack of user interaction makes it very hard to provide reliable recommendations
#
# **New item:**
#
# a new item is added to the system, it might have some content information but no interactions are present
#
#
# ***New user: ***
#
# a new user registers and has not provided any interaction yet, therefore it is not possible to provide personalized recommendations

# %% [markdown]
# **A popularity based model** does not suffer from cold start problems which means on day 1 of the business also it can recommend products on various different filters. There is no need for the user’s historical data. The popularity index used for our books dataset was **weighted rating.**

# %% [markdown]
# #Approach
#
# step:-1 We will filter those books which has got rating more than 250 and then we will calculate the average and will select the top 50 books.

# %% [markdown]
# ### ML Model - 1

# %%
#looking at the first two rows of the dataframe
final_df.head(2)

# %%
#creating new dataframe which contains only book title and book rating
recommended_books_df=final_df[['Book-Title','Book-Rating']]
recommended_books_df.head(2)

# %%
#counting the total ratings got by a book
recommended_books_df_rating_count=recommended_books_df.groupby('Book-Title').count().reset_index()
recommended_books_df_rating_count.rename(columns={'Book-Rating':'num_rating'},inplace=True)
recommended_books_df_rating_count[0:3]

# %%
#calculating the avg rating got by a book in a new dataframe
recommended_books_df_mean_count=recommended_books_df.groupby('Book-Title').mean().reset_index()
recommended_books_df_mean_count.rename(columns={'Book-Rating':'avg. rating'},inplace=True)
recommended_books_df_mean_count[0:3]

# %%
#merging the count and mean ratings dataframe and storing it into new dataframe popularity_df
popularity_df=recommended_books_df_mean_count.merge(recommended_books_df_rating_count,on='Book-Title')
popularity_df.head()

# %%
#cosidering only those books which have got ratings higher than 250
popularity_df=popularity_df[popularity_df['num_rating']>250]

# %%
popularity_df.head()

# %%
#sorting the dataframe in order of decreasing avg rating which will fetch top books according to avg ratings
popularity_df.sort_values('avg. rating',ascending=False,inplace=True)

# %%
popularity_df.shape

# %%
#the top 5 books according to avg ratings
popularity_df.head()

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# # **Popularity based Recommender System**
# **Weighted average rating method**
#
# Using Weighted average for each Book’s Average Rating
#
# W = Rv + Cm/(v + m)
#
# where
#
# W= Weighted Rating
#
# R = Average of the Books rating
#
# v = No of people who have rated the books(number of votes)
#
# m = minimum no of votes to be listed
#
# C = the mean rating across all the books

# %%
#finding the average rating and number of votes received by books
df_relevant_data = final_df.groupby(['Book-Title','Book-Author'],as_index=False).agg(avg_rating=('Book-Rating','mean'),ratings_count=('Book-Rating','count'))
v=df_relevant_data['ratings_count']
R=df_relevant_data['avg_rating']
C=df_relevant_data['avg_rating'].mean()
m=int(df_relevant_data['ratings_count'].quantile(0.90))#minimum number of votes to be listed
print(f'The average rating of all the books is {C} and the minimum number of votes required by the books to be listed is {m}  ')

# %%
#Calculating weighted average rating of the books
df_relevant_data['weighted_average']=round(((R*v)+ (C*m))/(v+m),2)

# %%
#filtering the dataframe in which the ratings count is greater than 250
df_relevant_data=df_relevant_data[df_relevant_data['ratings_count']>250]

# %%
df_relevant_data.head()

# %%
#sorting the books in descending order with respect to weighted average and printing top ten books acorrding to weighted avg.
df_relevant_data.sort_values(by='weighted_average',ascending=False).head(10)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %% [markdown]
# # **Author based recommender system**

# %%
def author_based(book_title,number,df_relevant_data=df_relevant_data):
  '''
  To recommend books from the same author as the book entered by the user
  '''
  author=df_relevant_data.loc[df_relevant_data['Book-Title']==book_title]['Book-Author'].unique()[0]
  author_df=df_relevant_data.loc[(df_relevant_data['Book-Author']==author)].sort_values(by='weighted_average',ascending=False)
  print(f'The author of the book {book_title} is {author}\n')
  print(f'Here are the top {number} books from the same author\n')
  top_rec=author_df.loc[(author_df['Book-Title']!=book_title),['Book-Title','weighted_average']].head(number)
  return(top_rec)

# %%
#get book name and number of books to recommend
book_title = 'Harry Potter and the Chamber of Secrets (Book 2)'
number =5
author_based(book_title,number)
# top_recommendations from the same author

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# #**Collabarative Based Filtering**

# %% [markdown]
# # What is Collaborative Filtering?
#
# Collaborative filtering is used by most recommendation systems to find similar patterns or information of the users, this technique can filter out items that users like on the basis of the ratings or reactions by similar users.
#
# An example of collaborative filtering can be to predict the rating of a particular user based on user ratings for other movies and others’ ratings for all movies. This concept is widely used in recommending
# movies, news, applications, and so many other items.
#
# Let’s take one example and understand more about what is Collaborative Filtering,
#
# let’s assume I have user U1, who likes movies m1,m2,m4. user U2 who likes movies m1,m3,m4, and user U3 who likes movie m1.
#
# So our job is to recommend which are the new movie to watch for the user U3 next.
#
# So here we can see users U1, U2, U3 watch/likes movies m1, so three have the same taste. now in user U1, U2 has like/watch movies m4, so user U3 could like movie m3 so I recommend movie m4, this is the flow of logic.
#
# The key idea of CF is Users who agreed in the past tend to also agree in the future.

# %% [markdown]
# ![1661676982Screenshot-2893.png](data:image/png;base64,...)

# %% [markdown]
# # Types of Filtering
# There are two types of Collaborative Filtering available:
#
#
#
# *   **User-User-based similarity/Collaborative Filtering**
# *  **Item-Item-based similarity/Collaborative Filtering**
#
#
#               The most popular Collaborative Filtering is item-item-based Collaborative Filtering.

# %% [markdown]
# # User-User-Based Collaborative Filtering
#
# user-user collaborative filtering is one kind of recommendation method which looks for similar users based on the items users have already liked or positively interacted with. Let’s take a one eg to understand user-user collaborative filtering.

# %% [markdown]
# Let’s assume given matrix A which contains user id and item id and rating or movies.
#
# ![687331_4VYSoN1gIgBDnQUBimudKw.png](data:image/png;base64,...)

# %% [markdown]
# Compute a User User similarity follow these steps, so find a similarity between two users we can use cosine similarity.
#
# so cosine similarity means the similarity between two vectors of inner product space, It is measured by the cosine of the angle between two vectors.
#
# ![67717cosine-similarity.png](data:image/png;base64,...)

# %% [markdown]
# ![71017Untitled.png](data:image/png;base64,...)

# %% [markdown]
# So we find a similarity matrix here and our task is to recommend a new movie /item to a user.
#
# Suppose you have to recommend a new top 5 similar movie or item for a user 10, so we have a similarity matrix a and we go in a similarity matrix in user 10 and find a top 5 similar values corresponding to the user 10.
#
# let’s suppose the top 5 similar to user10 is user 9,5,8,1,2. now you go into our user-item matrix and take all items of the user9,5,8,1,2 where they give a rating value and not watch by the user 10 and combine them. then we pick all those items and we recommended them for a user 10.
#
# But there can be a small problem with a user-user similarity base system, user interests change over time, and then similarity values also change, and this is impacted on the recommended system.

# %% [markdown]
# #Implementing user-user based recommendation system

# %%
#lets check the final dataframe
final_df.head(2)

# %%
#we are taking only those features which are relevant to our recommendation system
filtered_df=final_df[['User-ID','ISBN','Book-Rating','Book-Title']]
filtered_df.head(2)

# %%
#Now we will filter only those users who have rated atleat 200 times considering them to be mature users
#fetching the index of that users who have rated>200
x=filtered_df.groupby('User-ID').count()['Book-Rating']>200
matured_users=x[x].index
matured_users

# %%
#creating new data frame which has users rated more than 200
filtered_df_new=filtered_df[filtered_df['User-ID'].isin(matured_users)]
filtered_df_new.head(2)
filtered_df_new.shape

# %%
#now we will filter only those books which has got atleast 50 ratings
y=filtered_df_new.groupby('Book-Title').count()['Book-Rating']>50
famous_books=y[y].index
famous_books.head()

# %%
#creating new dataframe with books rating more than 50
df_new_and_final=filtered_df_new[filtered_df_new['Book-Title'].isin(famous_books)]
df_new_and_final.head(2)
df_new_and_final.shape

# %%
#creating a pivot table with user id as index and book title as columns and ratings as values
pt=df_new_and_final.pivot_table(index='User-ID',columns='Book-Title',values='Book-Rating')
pt.head()

# %%
#filling the nan values in pivot table with 0
pt.fillna(0,inplace=True)

# %%
pt.head(2)

# %%
pt.shape

# %% [markdown]
# The above pivot table can be considered as 461 users and their vector representation in 402 dimensions.We will calculate the similarity score between each users and recommend books to those users who hsve high similarity scores.

# %%
#importing library
from sklearn.metrics.pairwise import cosine_similarity

# %%
#calculating similarity score
similarity_score=cosine_similarity(pt)

# %%
#this is the similarity score of first users with other users
sorted(list(enumerate(similarity_score[0])),key=lambda x:x[1],reverse=True)[1:6]

# %%
np.where(pt.index==2276)[0][0]

# %%
#creating a function which will take user id as input then match it with the index and will fetch similar users according to cosine simmilarity value
def recommended_users(user_id):
  index=np.where(pt.index==user_id)[0][0]
  similar_users=sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:6]
  for i in similar_users:
    print(i[0])

# %%
#five similar users id of user id 2276
recommended_users(2276)

# %% [markdown]
# ## Implementing item_item based recommendation system

# %% [markdown]
# This is also very simple and very similar in idea with USER-USER Similarity Let’s dive deep into it.
#
# This item-item similarity is solve a problem that occurs in a user user-based similarity.
#
# Here we find a similarity matrix of items/books, here we find a similarity between the two books. to find a similarity we use a cosine distance between the two books.
#
# ![69012ezgif-7-62fd592648.png](data:image/png;base64,...)

# %%
#creating a pivot table with book title as index and user id as columns and ratings as values
pt=df_new_and_final.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')
pt.head()

# %%
#filling the nan values in pivot table with 0
pt.fillna(0,inplace=True)

# %%
pt.head(2)

# %%
pt.shape

# %% [markdown]
# The above pivot table can be considered as 402 books and their vector representation in 461 dimensions.We will calculate the similarity score between each users and recommend books to those users who hsve high similarity scores.

# %%
#calculating similarity score
similarity_score=cosine_similarity(pt)

# %%
#this is the similarity score of first book with other book
sorted(list(enumerate(similarity_score[0])),key=lambda x:x[1],reverse=True)[1:6]

# %%
#creating a function which will take book title as input then match it with the index and will fetch similar books according to cosine simmilarity value
def recommended_books(book_title):
  index=np.where(pt.index==book_title)[0][0]
  similar_users=sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1],reverse=True)[1:6]
  for i in similar_users:
    print(pt.index[i[0]])

# %%
#top books similar to 2nd chance
recommended_books('2nd Chance')

# %% [markdown]
# # **Collaborative Filtering model**

# %% [markdown]
# # **Model-based**
#
#
#
# *   In this approach, models are developed using different machine learning algorithms to recommend items to users. There are many model-based CF algorithms, like Neural Networks, Bayesian Networks, Clustering Techniques, and Latent Factor Models such as Singular Value Decomposition (SVD) and Probabilistic Latent Semantic Analysis.

# %% [markdown]
# # **Matrix Factorization**

# %% [markdown]
# *   Latent factor models compress user-item matrix into a low-dimensional representation in terms of latent factors. One advantage of using this approach is that instead of having a high dimensional matrix containing abundant number of missing values we will be dealing with a much smaller matrix in lower-dimensional space.
#
#
# *  A reduced presentation could be utilized for either user-based or item-based neighborhood algorithms. There are several advantages with this paradigm. It handles the sparsity of the original matrix better than memory based ones. Also comparing similarity on the resulting matrix is much more scalable especially in dealing with large sparse datasets.

# %% [markdown]
# # We will use a popular Latent Factor Model called Singular Value Decomposition or SVD

# %% [markdown]
# ![download (51).png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# An important decision is choosing the number of factors to factor the user-item matrix. The higher the number of factors, the more precise is the factorization in the original matrix reconstructions. Therefore, if the model is allowed to memorize too much details of the original matrix, it may not generalize well for data it was not trained on. Reducing the number of factors increases the model generalization.

# %% [markdown]
# # **Singular Value Decomposition (SVD)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Example Walkthrough
#
#
# Let’s calculate the SVD of the following matrix M.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#looking at the first five rows of the dataframe
df_new_and_final.head()

# %%
#data frame which has users rated more than 200 and books which has got ratings more than 50
df_new_and_final.shape

# %%
#importing library
from sklearn.model_selection import train_test_split

# %%
#splitting the dataframes into train and test datasets
interactions_train_df, interactions_test_df = train_test_split(df_new_and_final,
                                   
                                   test_size=0.20,
                                   random_state=42)

print('# interactions on Train set: %d' % len(interactions_train_df))
print('# interactions on Test set: %d' % len(interactions_test_df))

# %%
#Creating a sparse pivot table with users in rows and items in columns
users_items_pivot_matrix_df = interactions_train_df.pivot_table(index='User-ID', 
                                                          columns='ISBN', 
                                                          values='Book-Rating').fillna(0)

users_items_pivot_matrix_df.head()

# %%
users_items_pivot_matrix = users_items_pivot_matrix_df.values
users_items_pivot_matrix[:10]

# %%
#list of users id
users_ids = list(users_items_pivot_matrix_df.index)
users_ids[:10]

# %%
#importing library singular value decompositin
from scipy.sparse.linalg import svds

# %%
# The number of factors to factor the user-item matrix.
NUMBER_OF_FACTORS_MF = 15

#Performs matrix factorization of the original user item matrix
U, sigma, Vt = svds(users_items_pivot_matrix, k = NUMBER_OF_FACTORS_MF)

# %%
users_items_pivot_matrix.shape

# %%
U.shape

# %%
sigma = np.diag(sigma)
sigma.shape

# %%
Vt.shape

# %% [markdown]
# After the factorization, we try to to reconstruct the original matrix by multiplying its factors. The resulting matrix is not sparse any more. It was generated predictions for items the user have not yet interaction, which we will exploit for recommendations.

# %%
all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) 
all_user_predicted_ratings

# %%
#Converting the reconstructed matrix back to a Pandas dataframe
cf_preds_df = pd.DataFrame(all_user_predicted_ratings, columns = users_items_pivot_matrix_df.columns, index=users_ids).transpose()
cf_preds_df.head()

# %%
class CFRecommender:
    #Storing model name
    MODEL_NAME = 'Collaborative Filtering'
    
    def __init__(self, cf_predictions_df, items_df=None):
        #Creating attributes
        self.cf_predictions_df = cf_predictions_df
        self.items_df = items_df
        
    def get_model_name(self):
        '''This will return model name'''
        return self.MODEL_NAME
        
    def recommend_items(self, user_id, items_to_ignore=[], topn=10, verbose=False):
        # Get and sort the user's predictions
        sorted_user_predictions = self.cf_predictions_df[user_id].sort_values(ascending=False).reset_index().rename(columns={user_id: 'Book-Rating'})

        # Recommend the highest predicted rating content that the user hasn't seen yet.
        recommendations_df = sorted_user_predictions[~sorted_user_predictions['ISBN'].isin(items_to_ignore)].sort_values('Book-Rating', ascending = False).head(topn)

        if verbose:
            #runs only if verbose=True
            if self.items_df is None:
                raise Exception('"items_df" is required in verbose mode')
            #Merging 
            recommendations_df = recommendations_df.merge(self.items_df, how = 'left', 
                                                          left_on = 'ISBN', 
                                                          right_on = 'ISBN')[["ISBN",'Book-Title',	'Book-Author', 'Year-Of-Publication',	'Publisher']]

        return recommendations_df

#Creating object of the class   
cf_recommender_model = CFRecommender(cf_preds_df, books_df)

# %%
def get_items_interacted(person_id, interactions_df):
    '''
    This function will take user id as input and return interacted items
    '''
    interacted_items = interactions_df.loc[person_id]['ISBN']
    #Repetation is avoided by taking set
    return set(interacted_items if type(interacted_items) == pd.Series else [interacted_items])

# %%
#Indexing by personId to speed up the searches during evaluation
interactions_full_indexed_df = df_new_and_final.set_index('User-ID')
interactions_train_indexed_df = interactions_train_df.set_index('User-ID')
interactions_test_indexed_df = interactions_test_df.set_index('User-ID')

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# In Recommender Systems, there are a set metrics commonly used for evaluation. We choose to work with Top-N accuracy metrics, which evaluates the accuracy of the top recommendations provided to a user, comparing to the items the user has actually interacted in test set.
# This evaluation method works as follows:
#
#
#
# *   For each item the user has interacted in test set
# Sample 100 other items the user has never interacted.
# Ask the recommender model to produce a ranked list of recommended items, from a set composed of one interacted item and the 100 non-interacted items
# Compute the Top-N accuracy metrics for this user and interacted item from the recommendations ranked list
# Aggregate the global Top-N accuracy metrics

# %%
## We have split our data into Train & Test
# We used the training set to get the user-user similarity
# We will use the Test set to make recommendations

#lets suppose

# Total Number of books : 1000
# User 1 : Interacted with 100 books (900 not interacted)
# Training : 80 books
# Testing : 20 books

# Recommendation can be made from 900+20 books

# Topn : 100
# From 920 books our algorithm will find top 100 books to recommend
# From these 100 recommended books we will see how many of them are in the 20 books of the Test Data

# For example:
# 17 books from 20 are present in 100 recommended books
# Evaluation Metric : 17/100

# %%
#Indexing by personId to speed up the searches during evaluation
interactions_full_indexed_df = df_new_and_final.set_index('User-ID')
interactions_train_indexed_df = interactions_train_df.set_index('User-ID')
interactions_test_indexed_df = interactions_test_df.set_index('User-ID')

# %% [markdown]
# The Top-N accuracy metric choosen was **Recall@N** which evaluates whether the interacted item is among the top N items (hit) in the ranked list of 101 recommendations for a user.

# %%
# Recall@N : Evaluation Metric for recommendation systems where N is the total number of
# recommendations made by the model

# %%
# Function for getting the set of books which a user has not interacted with
def get_not_interacted_items_sample(person_id, sample_size, seed=42):
    #Storing interacted items
    interacted_items = get_items_interacted(person_id,interactions_full_indexed_df)
    #Getting set of all items
    all_items=set(interactions_full_indexed_df["ISBN"])
    #Obtaining non interacted items
    non_interacted_items = all_items - interacted_items

    random.seed(seed)
    #Selecting random sample of given sample_size
    non_interacted_items_sample = random.sample(non_interacted_items, sample_size)
    return set(non_interacted_items_sample)

# %%
import random

# %%
#Top-N accuracy metrics
EVAL_RANDOM_SAMPLE_NON_INTERACTED_ITEMS = 100

class ModelEvaluator:

    # Function to verify whether a particular item_id was present in the set of top N recommended items
    def _verify_hit_top_n(self, item_id, recommended_items, topn):        
            try:
                #Stores index of item id if it is present in the recommended_items
                index = next(i for i, c in enumerate(recommended_items) if c == item_id)
            except:
                #If item id is not found in the recommended list
                index = -1
            #checking whether index is present in the topN items or not
            hit = int(index in range(0, topn))
            return hit, index
    
    # Function to evaluate the performance of model for each user
    def evaluate_model_for_user(self, model, person_id):
        
        # Getting the items in test set
        interacted_values_testset =interactions_test_indexed_df.loc[person_id]
        
        #Obtaining unique interacted items by the user
        if type(interacted_values_testset['ISBN']) == pd.Series:
            person_interacted_items_testset = set(interacted_values_testset['ISBN'])
        else:
            person_interacted_items_testset = set([(interacted_values_testset['ISBN'])])
            
        interacted_items_count_testset = len(person_interacted_items_testset) 

        # Getting a ranked recommendation list from the model for a given user
        person_recs_df = model.recommend_items(person_id, items_to_ignore=get_items_interacted(person_id, interactions_train_indexed_df),topn=10000000000)

        hits_at_5_count = 0
        hits_at_10_count = 0
        
        # For each item the user has interacted in test set
        for item_id in person_interacted_items_testset:
            
            # Getting a random sample of 100 items the user has not interacted with
            non_interacted_items_sample = get_not_interacted_items_sample(person_id, sample_size=100, seed=42)

            # Combining the current interacted item with the 100 random items
            items_to_filter_recs = non_interacted_items_sample.union(set([item_id]))

            # Filtering only recommendations that are either the interacted item or from a random sample of 100 non-interacted items
            valid_recs_df = person_recs_df[person_recs_df['ISBN'].isin(items_to_filter_recs)]                    
            valid_recs = valid_recs_df['ISBN'].values
            
            # Verifying if the current interacted item is among the Top-N recommended items
            hit_at_5, index_at_5 = self._verify_hit_top_n(item_id, valid_recs, 5)
            #Counting hit at 5
            hits_at_5_count += hit_at_5
            hit_at_10, index_at_10 = self._verify_hit_top_n(item_id, valid_recs, 10)
            #Counting hit at 10
            hits_at_10_count += hit_at_10

        # Recall is the rate of the interacted items that are ranked among the Top-N recommended items
        recall_at_5 = hits_at_5_count / float(interacted_items_count_testset)
        recall_at_10 = hits_at_10_count / float(interacted_items_count_testset)
         #Creating a dictionary
        person_metrics = {'hits@5_count':hits_at_5_count, 
                          'hits@10_count':hits_at_10_count, 
                          'interacted_count': interacted_items_count_testset,
                          'recall@5': recall_at_5,
                          'recall@10': recall_at_10}
        return person_metrics

    
    # Function to evaluate the performance of model at overall level
    def evaluate_model(self, model):
        
        people_metrics = []
        
        #Calculating metrics for all users in the test set
        for idx, person_id in enumerate(list(interactions_test_indexed_df.index.unique().values)):    
            #Returns dictionary containing person_metrics for each user
            person_metrics = self.evaluate_model_for_user(model, person_id)  
            #Adds user_id to the dictionary
            person_metrics['_person_id'] = person_id
            #Appends each dictionary to the list
            people_metrics.append(person_metrics)
            
        print('%d users processed' % idx)
        #Creates dataframe containing value of metrics for all the users using the list of dictionaries
        detailed_results_df = pd.DataFrame(people_metrics).sort_values('interacted_count', ascending=False)
        
        #Calculating global recall@5 and global recall@10
        global_recall_at_5 = detailed_results_df['hits@5_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        global_recall_at_10 = detailed_results_df['hits@10_count'].sum() / float(detailed_results_df['interacted_count'].sum())
        
        #Creates dictionary containing global metrics
        global_metrics = {'modelName': model.get_model_name(),
                          'recall@5': global_recall_at_5,
                          'recall@10': global_recall_at_10}    
        return global_metrics, detailed_results_df
    
model_evaluator = ModelEvaluator()

# %%
print('Evaluating Collaborative Filtering (SVD Matrix Factorization) model...')
cf_global_metrics, cf_detailed_results_df = model_evaluator.evaluate_model(cf_recommender_model)

print('\nGlobal metrics:\n%s' % cf_global_metrics)
cf_detailed_results_df.head(10)

# %% [markdown]
# # **Challenges**
# There are a variety of challenges when working with collaborative filtering approaches in recommendation systems, the most common one is the cold start problem. The cold start problem refers to a recommendation engines inability to generate decent predictions for new items / users. Or users / items which have a low amount of interactions, essentially the user-item matrix it generates is very sparse. This is because of a lack of information for new items or product releases.
#
#
# Another common problem with collaborative filtering which stems from the cold start problem is the diversity of the recommendations. This approach recommends products / users based on the historical interactions other users / products have had, essentially meaning that highly popular products will almost always get recommended over other products with a little too few interactions.
#
# Scalability is a common issue for collaborative filtering algorithms, as the number of users, products and interactions increase, the size of the user-item matrix increases proportionally. This causes issues when data expands substantially and will yield an increase of computation time. Usually, the trade off with working larger datasets is that there should be an increase in performance while there’s a decrease in speed and vice versa for small datasets.

# %% [markdown]
# # **Content Based Filtering**

# %% [markdown]
# This method uses only information about the description and attributes of the items users has previously consumed to model user's preferences. In other words, these algorithms try to recommend items that are similar to those that a user liked in the past (or is examining in the present). In particular, various candidate items are compared with items previously rated by the user and the best-matching items are recommended.
#
#
#
# *   Content-based filtering approaches leverage description or attributes from items the user has interacted to recommend similar items. It depends only on the user previous choices, making this method robust to avoid the cold-start problem. For textual items, like articles, news and books, it is simple to use the raw text to build item profiles and user profiles.
#
#
# *  Here we are using a very popular technique in information retrieval (search engines) named TF-IDF. This technique converts unstructured text into a vector structure, where each word is represented by a position in the vector, and the value measures how relevant a given word is for an article. As all items will be represented in the same Vector Space Model, it is to compute similarity between articles.

# %%
#creating a copy of the original dataframe
df_content=final_df.copy()

# %%
#checking duplicate rows
df_content.duplicated().sum()

# %%
#filtering the dataframe with some columns
new_df=df_content[['User-ID','ISBN','Book-Title','Book-Author','Publisher']]

# %%
#checking the null values
new_df.isnull().sum()

# %%
new_df.head()

# %%
#now replacing the space between the names with nothing so that the two words common in two different names can be distinguished
new_df['Book-Title_compressed']=new_df['Book-Title'].apply(lambda x:x.replace(' ',''))
new_df['Book-Author']=new_df['Book-Author'].apply(lambda x:x.replace(' ',''))
new_df['Publisher']=new_df['Publisher'].apply(lambda x:x.replace(' ',''))

# %%
new_df.head()

# %%
#creating the tags for each row which will contain book name,author name and publisher so that it can be vectorised
new_df['tags']=new_df['Book-Title_compressed']+' '+new_df['Book-Author']+' '+new_df['Publisher']

# %%
new_df.head()

# %%
new_df['tags'][44]

# %%
#installing library for text preprocessing
# !pip install texthero

# %%
# !pip install -U spacy

# %%
#importing library
import spacy

# %%
#importing library
import texthero

# %%
import texthero as hero

# %%
#now doing texpreprocessing with texthero as it includes lowering of case,removing stopwords,punctuation,stemming and etc.
new_df['cleaned_data']=new_df['tags'].pipe(hero.clean)

# %%
new_df.head()

# %%
#importing countvectorizer for conversion of text into vectors
from sklearn.feature_extraction.text import CountVectorizer

# %%
#creating an object of class selecting only 5000 features accorting to which all tags will be converted into vectors
cv=CountVectorizer(max_features=5000)

# %%
#converting text into vectors
vectors=cv.fit_transform(new_df['cleaned_data']).toarray()

# %%
vectors[0]

# %%
cv.vocabulary_

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
#similarity=cosine_similarity(vectors)

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **In conclusion, a book recommendation system is a valuable tool for individuals who are looking to discover new books that align with their interests and preferences. By using algorithms that analyze user behavior and book characteristics, these systems can suggest books that are likely to be of interest to a particular user.**
#
# **Some key considerations when building a book recommendation system include the types of data to collect (such as user ratings, browsing history, and demographic information), the algorithm used to generate recommendations, and the evaluation metrics used to measure the effectiveness of the system.**

# %% [markdown]
# Content-based filtering and collaborative filtering are two common approaches used in recommendation systems. Here are the advantages and disadvantages of each:
#
# **Content-based filtering:**
#
#     Advantages:
#
#
#
#
# *   It recommends items based on user preferences and item features, such as genres, authors, and themes.
#
#
#
#
#
# *   It can provide personalized recommendations that align with a user's interests.
# It can handle the cold start problem, where new items or users have little to no historical data.
#
#         Disadvantages:
#
#
#
# *  It may be limited in recommending items that are similar to what a user has previously liked or interacted with.
#
# *  It may not capture unexpected or serendipitous recommendations that a user may be interested in.
# It may require a significant amount of information about the items being recommended, which can be difficult to obtain or maintain.
#
#
# **Collaborative filtering:**
#
#       Advantages:
#
#
#
#
# *  It recommends items based on the behavior of similar users, which can capture unexpected or serendipitous recommendations.
# It can be effective in recommending popular items that many users have interacted with.
# It can handle the sparsity problem, where users have little overlap in their interactions.
#
#        Disadvantages:
#
#
# *   It may not be effective in recommending niche or personalized items that only a small subset of users have interacted with.
# It may be vulnerable to shilling attacks or manipulation by users who intentionally provide biased feedback.
# It may suffer from the cold start problem, where new items or users have little to no historical data.

# %% [markdown]
# Overall, the choice between content-based and collaborative filtering depends on the specific needs of the recommendation system and the type of items being recommended. In practice, hybrid approaches that combine both methods may be the most effective.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
